# %% [markdown]
# # 🔬🧪🥼 Laboratorio 1: Primeras nociones de Programación Orientada a Objetos
# ## Contexto: Sistema básico de salas
#
# **Duración sugerida:** 2 hora 20 minutos
# **Modalidad:** trabajo guiado en Google Colab, con respaldo en GitHub
#
# ## 🎯 Objetivo
# Comprender las primeras nociones de programación orientada a objetos mediante la abstracción de un contexto cercano, identificando clases, objetos, atributos, métodos e interfaz básica, y construyendo una primera estructura simple en Python.

# %% [markdown]
# ## 🤔 1. Antes de programar: pensar el problema
#
# Una institución desea representar sus salas en un sistema simple. Cada sala tiene información relevante, por ejemplo:
#
# - nombre o código
# - capacidad
# - ubicación
# - disponibilidad
# - tipo de sala
#
# Además, se espera que el sistema pueda realizar algunas acciones simples, por ejemplo:
#
# - mostrar la información de la sala
# - reservar la sala
# - liberar la sala
#
# ### Responde con tus palabras
# 1. ¿Qué es una sala dentro de este sistema?
# 2. ¿Qué características son importantes para representarla?
# 3. ¿Qué acciones debería poder realizar?
# 4. ¿Qué detalles del mundo real no son necesarios todavía?

# %% [markdown]
# Respuestas

# %% [markdown]
# **Instrucciones de entrega:** El laboratorio debe ser desarrollado y entregado en un archivo `.ipynb`, alojado en el repositorio personal de GitHub de cada estudiante.
#
# Las preguntas de reflexión o análisis deben responderse en **celdas de texto (Markdown)**, mientras que toda implementación, prueba y programación debe realizarse en **celdas de código**.

# %% [markdown]
# ## 🤔 1. Antes de programar: pensar el problema
#
# Una institución desea representar sus salas en un sistema simple. Cada sala tiene información relevante, por ejemplo:
#
# - nombre o código
# - capacidad
# - ubicación
# - disponibilidad
# - tipo de sala
#
# Además, se espera que el sistema pueda realizar algunas acciones simples, por ejemplo:
#
# - mostrar la información de la sala
# - reservar la sala
# - liberar la sala
#
# ### Responde con tus palabras
# 1. ¿Qué es una sala dentro de este sistema?
# 2. ¿Qué características son importantes para representarla?
# 3. ¿Qué acciones debería poder realizar?
# 4. ¿Qué detalles del mundo real no son necesarios todavía?

# %% [markdown]
# 1. La sala dentro de este sistema es una entidad digital que representa un espacio físico con propiedades que son relevantes para su gestión, como su nombre, capacidad, ubicación, disponibilidad y tipo.
# 2. Para el problema diría que todas las caracteristicas mencionadas son importantes que. Sin el nombre no se diferencia de otras salas, la capacidad (cuántas personas puede albergar), su ubicación (como se llega a la sala), su disponibilidad (si está libre u ocupada) y el tipo de sala (aula, laboratorio, auditorio).
# 3. Mostrar la información de la sala (para conocer sus detalles), reservar la sala (cambiar su estado a no disponible u ocupada) y liberar la sala (cambiar su estado a disponible o desocupada).
# 4. Los detalles de la sala, que se sepa su disponibilidad, su ubicación y el nombre de la sala es suficiente.

# %% [markdown]
# ## 2. Abstracción
#
# **Idea clave:** abstraer no es copiar toda la realidad, sino elegir las características relevantes para resolver un problema.
#
# Por ejemplo, una sala real puede tener muchos detalles:
# - color,
# - número de enchufes,
# - ventanas,
# - tipo de sillas,
# - proyector,
# - capacidad,
# - ubicación,
# - disponibilidad.
#
# Pero en esta primera versión del sistema, no todo eso es necesario.
#
# ### Actividad
# Escribe una breve reflexión:
#
# - ¿Qué atributos sí incluirías?
# - ¿Cuáles dejarías fuera?
# - ¿Por qué?

# %% [markdown]
# ## 3. Conceptos iniciales
#
# ### Definiciones básicas
# - **Clase:** el molde o definición general.
# - **Objeto:** una instancia concreta creada a partir de una clase.
# - **Atributo:** una característica o dato del objeto.
# - **Método:** una acción o comportamiento del objeto.
# - **Interfaz (idea inicial):** el conjunto de acciones con las que se puede interactuar con el objeto.
#
# ### Preguntas de chequeo
# 1. ¿Cuál sería la clase principal en este problema?
# 2. ¿Qué objetos concretos podríamos crear?
# 3. ¿Qué serían atributos?
# 4. ¿Qué serían métodos?

# %%
# Escribe aquí tus respuestas si lo deseas.
# Puedes usar comentarios o variables de texto.

respuesta_1 = "La clase principal sería 'Sala'."
respuesta_2 = "Podríamos crear objetos concretos como: 'sala_a101', 'lab_info', 'auditorio'."
respuesta_3 = "Los atributos serían las características de la sala, como: nombre/código, capacidad, ubicación, disponibilidad, tipo de sala."
respuesta_4 = "Los métodos serían las acciones que la sala puede realizar, como: mostrar_info(), reservar(), liberar()."

# %% [markdown]
# ## 4. Primera estructura de una clase
#
# Observa esta estructura base:

# %%
class Sala:
    def __init__(self, nombre, capacidad, ubicacion, disponible=True):
        self.nombre = nombre
        self.capacidad = capacidad
        self.ubicacion = ubicacion
        self.disponible = disponible

# %% [markdown]
# ### Preguntas
# 1. ¿Qué representa la clase `Sala`?
# 2. ¿Qué hace `__init__`?
# 3. ¿Qué representan `self.nombre`, `self.capacidad`, etc.?
# 4. ¿Qué diferencia existe entre la clase y un objeto?
#
# R1:
# La clase Sala representa el plano o molde genérico para crear diferentes instancias de salas. Define la estructura y el comportamiento que todas las salas tendrán en nuestro sistema.
#
# R2:
# __init__ es el método constructor de la clase. Se ejecuta automáticamente cada vez que se crea un nuevo objeto. Su propósito es inicializar los atributos del objeto con los valores que se le pasan como argumentos.
#
# R3:
# Representan los atributos de una instancia específica de la clase Sala. self hace referencia al objeto actual que se está creando o manipulando. Self.nombre guarda el nombre de esa sala particular y  self.capacidad guarda su capacidad.
#
# R4:
# La clase es la definición abstracta, la plantilla o el tipo de dato.Es la idea de una sala. Un objeto es una instancia concreta y tangible de esa clase (por ejemplo, sala_a101 o lab_info). Es una sala real que ha sido creada siguiendo el molde de la clase Sala, con sus propios valores para los atributos como nombre, capacidad, etc.

# %% [markdown]
# ## 5. Completa la clase
#
# Ahora agrega métodos simples a la clase.
#
# ### Tareas
# - Crear un método `mostrar_info()` que imprima la información principal de la sala.
# - Crear un método `reservar()` que deje la sala como no disponible si estaba libre.
# - Crear un método `liberar()` que deje la sala disponible nuevamente.
#
# ### Pista
# Recuerda que dentro de los métodos puedes acceder a los atributos usando `self`.

# %%
class Sala:
    def __init__(self, nombre, capacidad, ubicacion, disponible=True):
        self.nombre = nombre
        self.capacidad = capacidad
        self.ubicacion = ubicacion
        self.disponible = disponible

    def mostrar_info(self):
        estado = "Disponible" if self.disponible else "No disponible"
        print(f"--- Información de la Sala ---")
        print(f"Nombre: {self.nombre}")
        print(f"Capacidad: {self.capacidad} personas")
        print(f"Ubicación: {self.ubicacion}")
        print(f"Estado: {estado}")
        print(f"-----------------------------")

    def reservar(self):
        if self.disponible:
            self.disponible = False
            print(f"La sala '{self.nombre}' ha sido reservada.")
        else:
            print(f"La sala '{self.nombre}' ya está reservada.")

    def liberar(self):
        if not self.disponible:
            self.disponible = True
            print(f"La sala '{self.nombre}' ha sido liberada.")
        else:
            print(f"La sala '{self.nombre}' ya está disponible.")

# %% [markdown]
# ## 6. Crear primeros objetos
#
# Una vez que completes la clase, crea al menos tres objetos distintos.
# Por ejemplo:
#
# - una sala de clases
# - un laboratorio
# - un auditorio
#
# Luego prueba sus métodos.

# %%
# Crea aquí tus objetos
# Ejemplo de estructura: # sala_a101 = Sala("A101", 35, "Edificio A")
# lab_info = Sala("Lab Info 2", 25, "Edificio B")
# auditorio = Sala("Auditorio Central", 120, "Edificio C")

sala_clases = Sala("Aula 201", 40, "Edificio Principal", disponible=True)
lab_informatica = Sala("Lab Cómputo 1", 20, "Edificio Tecnología", disponible=False)
auditorio_magno = Sala("Auditorio Principal", 150, "Edificio Central")

# %% [markdown]
# ## 7. Pruebas
#
# Realiza pruebas simples:
# - mostrar información
# - reservar una sala
# - volver a mostrar información
# - liberar una sala
# - mostrar nuevamente
#
# ### Pregunta
# ¿Qué cambia en el estado del objeto cuando reservas o liberas una sala?

# %%
# Escribe aquí tus pruebas

sala_clases.mostrar_info()
lab_informatica.mostrar_info()
auditorio_magno.mostrar_info()

print("Reservando salas")
sala_clases.reservar() # Debería reservarse
lab_informatica.reservar() # Debería decir que ya está reservada

print("Estado después de reservar")
sala_clases.mostrar_info()
lab_informatica.mostrar_info()

print("Liberando salas")
sala_clases.liberar() # Debería liberarse
auditorio_magno.liberar() # Debería decir que ya está disponible

print("Estado final")
sala_clases.mostrar_info()
auditorio_magno.mostrar_info()
# Out:
# --- Información de la Sala ---
# Nombre: Aula 201
# Capacidad: 40 personas
# Ubicación: Edificio Principal
# Estado: Disponible
# -----------------------------
# --- Información de la Sala ---
# Nombre: Lab Cómputo 1
# Capacidad: 20 personas
# Ubicación: Edificio Tecnología
# Estado: No disponible
# -----------------------------
# --- Información de la Sala ---
# Nombre: Auditorio Principal
# Capacidad: 150 personas
# Ubicación: Edificio Central
# Estado: Disponible
# -----------------------------
# Reservando salas
# La sala 'Aula 201' ha sido reservada con éxito.
# La sala 'Lab Cómputo 1' ya está reservada y no puede ser reservada nuevamente.
# Estado después de reservar
# --- Información de la Sala ---
# Nombre: Aula 201
# Capacidad: 40 personas
# Ubicación: Edificio Principal
# Estado: No disponible
# -----------------------------
# --- Información de la Sala ---
# Nombre: Lab Cómputo 1
# Capacidad: 20 personas
# Ubicación: Edificio Tecnología
# Estado: No disponible
# -----------------------------
# Liberando salas
# La sala 'Aula 201' ha sido liberada.
# La sala 'Auditorio Principal' ya está disponible.
# Estado final
# --- Información de la Sala ---
# Nombre: Aula 201
# Capacidad: 40 personas
# Ubicación: Edificio Principal
# Estado: Disponible
# -----------------------------
# --- Información de la Sala ---
# Nombre: Auditorio Principal
# Capacidad: 150 personas
# Ubicación: Edificio Central
# Estado: Disponible
# -----------------------------

# %% [markdown]
# ## 8. Reflexión conceptual
#
# Responde brevemente:
#
# 1. ¿Qué diferencia hay entre la clase `Sala` y un objeto como `sala_a101`?
# 2. ¿Por qué la capacidad es un atributo y no un método?
# 3. ¿Por qué `reservar()` es un método y no un atributo?
# 4. ¿Qué entiendes por interfaz del objeto en esta actividad?
#
# R1:
# La clase sala abarca el concepto de todos los objetos que son "salas" y el objeto es lo que está dentro de la clase que es la sala "física".
#
# R2:
# Porque es una caracteristica, la capacidad no es una acción que se realice a la sala.
#
# R3:
# Porque es una acción que se le realiza a la sala, no es una caracteristica como la capacidad por ejemplo.
#
# R4:
# La interfaz sería lo que la gente ve al reservar la sala, no ve el código que hay detrás para reservar la sala. Es como una instancia para que la gente interactue con el objeto.

# %% [markdown]
# ## 9. Desafío opcional
#
# Si terminas antes, intenta una o más de estas mejoras:
#
# - agregar el atributo `tipo_sala`
# - validar que la capacidad no sea negativa
# - mostrar la información en un formato más claro
# - crear una lista con varias salas y recorrerla para imprimir sus datos
# - impedir que una sala ya reservada se vuelva a reservar sin aviso

# %%
# Espacio para desafío opcional

# %% [markdown]
# ## 10. Cierre
#
# La meta de este laboratorio no es aprender toda la Programación Orientada a Objetos en una sesión, sino comenzar a mirar un problema del mundo real y pensar cómo representarlo mediante objetos.
#
# ### Entrega
# - Notebook completo y ordenado.
# - Respuestas breves a las preguntas conceptuales.
# - Código funcional para la clase y los objetos creados.
